# %% [markdown]
# # Function Calling：大模型的手和脚
#
# ## 1. 什么是大模型？
# 基于decoder-only的transformer架构，通过大量数据训练得到的模型，模型参数量较大。因为decoder-only的架构是生成下一个token，而token仅仅是文本信息，所以单纯的大模型只能跟你对话（Chatbot）。大模型如果仅仅是一个对话工具，无法对实际场景有真正的帮助。
#
# ## 2. 如何真正能让大模型落地使用？
# 依靠大模型强大的文本理解和推理规划能力，调用已有的工具（函数、API、数据库、文件等），去帮助你完成一个实际任务。 -> Function Calling
#
# 比如：上网查资料、打开IDE编写代码并执行、调用远程的API接口
#
# ## 3. 实际案例：旅游攻略
# LLM：
# prompt: 你是一个旅游攻略专家，现在需要你根据用户所制定的旅游地点，生成一个旅游攻略。
# response：随机给你生成一个旅游地点的攻略
#
# LLM+Function Calling=Agent:
#
# prompt：你是一个旅游攻略专家，现在需要你根据用户所制定的旅游地点，生成一个旅游攻略。
# response：
# 第一步我需要调用浏览器工具（入参），调用爬虫工具（入参），调用word工具（入参） -> 转换成执行函数、调用API、使用软件工具
#
#
# 1. 根据景点信息，上网查看游客的评论，并形成一个word文档  工具：浏览器，爬取网页内容，word
# 2. 根据景点信息，上网搜索别人的旅游攻略，形成一个excel文档 工具：浏览器，爬取网页内容，excel
# 3. 将已有的信息交给大模型进行汇总，形成一个旅游攻略，并形成一个ppt 工具：大模型，PPT
